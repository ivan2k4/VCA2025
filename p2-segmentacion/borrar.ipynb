# %%
import random
import numpy as np
import matplotlib.pyplot as plt

def f():
    return random.random()

ts = np.arange(0.1, 1, 0.1)
results = np.zeros((len(ts), 2))
for i, t in enumerate(ts):
    results[i] = [t, f()]

print(results)
m = np.argmax(results[:, 1], axis=0)

print(results[m])


plt.plot(results[:, 0], results[:, 1])
# Out:
# [[0.1        0.63179981]
#  [0.2        0.6468297 ]
#  [0.3        0.82202745]
#  [0.4        0.82647379]
#  [0.5        0.05015798]
#  [0.6        0.38024364]
#  [0.7        0.56863248]
#  [0.8        0.05299651]
#  [0.9        0.36398864]]
# [0.4        0.82647379]
